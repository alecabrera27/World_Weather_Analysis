# %%
# Import dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list 
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Import the requests library 
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call. 
#url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# %%
len(city_data)

# %%
# Create an empty list to hold the weather data.
city_df = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

counter=0

for city in cities:
    
    
    city_weather = requests.get(query_url + city).json()
        
    
    try:
        
        
        city_dictionary= {
        "City":city_weather["name"],
        "Lat":city_weather["coord"]["lat"],
        "Lon":city_weather["coord"]["lon"],
        "Max_temp":city_weather["main"]["temp_max"],
        "Humidity": city_weather["main"]["humidity"],
        "Clouds": city_weather["clouds"]["all"],
        "Wind Speed": city_weather["wind"]["speed"],
        "Country": city_weather["sys"]["country"],
        "Current Description": city_weather["weather"][0]["description"]
        
        }
    
        city_df.append(city_dictionary)
        counter= counter +1
        print(f'{counter} city name {city_weather["name"]} | {city_weather["id"]}')
              
    except:
        
        print("Data not Found:" + city)
city_df
# Out:
# Beginning Data Retrieval
# -----------------------------
# 1 city name Coahuayana Viejo | 4013679
# 2 city name Bluff | 2206939
# 3 city name Tual | 1623197
# 4 city name Pangai | 4032369
# 5 city name Dabat | 340358
# 6 city name Hithadhoo | 1282256
# 7 city name Barrow | 5880054
# 8 city name Puerto Ayora | 3652764
# 9 city name Bredasdorp | 1015776
# 10 city name Huai Mek | 1610661
# 11 city name Prince Rupert | 6113406
# 12 city name Tautira | 4033557
# 13 city name Kapaa | 5848280
# 14 city name Ketchikan | 5554428
# 15 city name San Policarpo | 1688696
# 16 city name Ushuaia | 3833367
# 17 city name Los Llanos de Aridane | 2514651
# 18 city name Saravan | 174726
# 19 city name Hasaki | 2112802
# 20 city name Rikitea | 4030556
# 21 city name East London | 1006984
# 22 city name Atuona | 4020109
# 23 city name Kwang Binh | 1582886
# 24 city name Ribeira Grande | 3372707
# 25 city name Klaksvík | 2618795
# 26 city name Wasilla | 5877641
# 27 city name Nome | 5870133
# 28 city name Jamestown | 5122534
# Data not Found:grand river south east
# 29 city name Butaritari | 2110227
# 30 city name Esperance | 2071860
# 31 city name Batemans Bay | 2176639
# 32 city name Siniscola | 3166509
# 33 city name Kamenka | 553766
# 34 city name Merke | 1520969
# 35 city name Tasiilaq | 3424607
# 36 city name Salinópolis | 3389822
# 37 city name Pevek | 2122090
# Data not Found:saleaula
# 38 city name Fort Nelson | 5955902
# 39 city name Khor | 2022317
# Data not Found:umzimvubu
# 40 city name Kosino | 544119
# 41 city name Vardø | 777019
# 42 city name Vaini | 4032243
# Data not Found:amderma
# 43 city name Pathein | 1328421
# 44 city name Sokółka | 758651
# 45 city name Lebu | 3883457
# 46 city name Busselton | 2075265
# 47 city name Cape Town | 3369157
# 48 city name Avarua | 4035715
# 49 city name Cabo San Lucas | 3985710
# 50 city name Chul'man | 2025261
# 51 city name Hauterive | 3013748
# 52 city name Lima | 3936456
# 53 city name Iqaluit | 5983720
# 54 city name Erzincan Province | 315372
# 55 city name Itarema | 3393692
# 56 city name Albany | 5106841
# 57 city name Torbay | 6167817
# 58 city name Mabaruma | 3377301
# 59 city name Mataura | 6201424
# 60 city name Saint Paul Harbor | 5866583
# 61 city name Fukuechō | 1863997
# 62 city name Caiapônia | 3468234
# 63 city name Abnūb | 362973
# 64 city name Kloulklubed | 7671223
# 65 city name Banda Aceh | 1215502
# 66 city name Tiksi | 2015306
# 67 city name Grindavik | 3416888
# 68 city name Arraial do Cabo | 3471451
# Data not Found:illoqqortoormiut
# 69 city name Hermanus | 3366880
# 70 city name Mount Gambier | 2156643
# 71 city name Bereda | 3105522
# 72 city name Qaanaaq | 3831208
# 73 city name Lorengau | 2092164
# 74 city name Udachny | 2014624
# 75 city name Aksu | 1529660
# 76 city name Merauke | 2082539
# 77 city name Khuzdar | 7082481
# 78 city name Vestmanna | 2610343
# 79 city name San Jose | 5392171
# 80 city name Vila Franca do Campo | 3372472
# 81 city name Berbera | 64435
# 82 city name Lompoc | 5367788
# 83 city name Carnarvon | 2074865
# 84 city name Thompson | 6165406
# 85 city name Narsaq | 3421719
# 86 city name Antofagasta | 3899539
# 87 city name Marawi | 1701054
# 88 city name Pangnirtung | 6096551
# 89 city name Ulladulla | 2145554
# 90 city name Saskylakh | 2017155
# 91 city name Arrondissement du Havre | 3013633
# 92 city name Yacuiba | 3901178
# 93 city name Sisimiut | 3419842
# 94 city name New Norfolk | 2155415
# 95 city name Karratha | 6620339
# 96 city name Port Alfred | 964432
# 97 city name Kiama | 2161515
# 98 city name Fare | 4034496
# 99 city name Talnakh | 1490256
# Data not Found:taolanaro
# 100 city name Severo-Kuril'sk | 2121385
# 101 city name Kamaishi | 2112444
# Data not Found:samusu
# 102 city name Dunedin | 2191562
# 103 city name Deputatsky | 2028164
# 104 city name Chillicothe | 4828890
# 105 city name Dolinsk | 2125945
# 106 city name Tegul'det | 1489822
# 107 city name Tutóia | 3385899
# Data not Found:sataua
# 108 city name Namatanai | 2090021
# 109 city name George Town | 1735106
# 110 city name Sinnamary | 3380290
# 111 city name Kavaratti | 1267390
# 112 city name Nikolskoye | 546105
# 113 city name Beloha | 1067565
# 114 city name Kavieng | 2094342
# 115 city name Neyshabur | 122285
# Data not Found:cam pha
# 116 city name Tuktoyaktuk | 6170031
# 117 city name Ponta do Sol | 2264557
# 118 city name Ayan | 2027316
# 119 city name San Patricio | 4726521
# 120 city name Plettenberg Bay | 964712
# 121 city name Gimli | 5961417
# 122 city name Lefka | 146392
# 123 city name Dikson | 1507390
# 124 city name Hudson Bay | 5978133
# 125 city name Priladozhskiy | 866055
# 126 city name Stornoway | 2636790
# 127 city name Srandakan | 1626493
# Data not Found:nguiu
# Data not Found:urfa
# 128 city name Hobart | 2163355
# 129 city name Vestmannaeyjar | 3412093
# 130 city name Tabas | 113659
# Data not Found:warqla
# 131 city name Lavrentiya | 4031637
# 132 city name Laas | 3175096
# 133 city name Dhārchula | 1272864
# Data not Found:khonuu
# 134 city name Hilo | 5855927
# 135 city name Ust'-Koksa | 1488167
# 136 city name Altus | 4529292
# 137 city name Caravelas | 3466980
# 138 city name Ahipara | 2194098
# 139 city name Brebu | 683731
# 140 city name Haines Junction | 5969025
# 141 city name Aasiaat | 3424901
# 142 city name Vilyuysk | 2013392
# Data not Found:lolua
# 143 city name Kaitangata | 2208248
# 144 city name Port Elizabeth | 964420
# 145 city name Zhigansk | 2012530
# 146 city name Lata | 2738381
# 147 city name Yellowknife | 6185377
# 148 city name Sault Ste. Marie | 6141439
# 149 city name Tshikapa | 204953
# 150 city name Winnemucca | 5710360
# 151 city name Hong Kong | 1819729
# 152 city name Mar del Plata | 3430863
# 153 city name Porto-Novo | 2392087
# 154 city name São Filipe | 3374210
# 155 city name Kimbe | 2093967
# 156 city name Mimongo | 2398430
# Data not Found:tsihombe
# 157 city name Honiara | 2108502
# 158 city name Staryy Nadym | 1490918
# 159 city name Samarai | 2132606
# 160 city name Mercedes | 3430708
# 161 city name Aksarka | 1512019
# 162 city name Mamlyutka | 1521153
# Data not Found:nizhneyansk
# 163 city name Chokurdakh | 2126123
# 164 city name Windhoek | 3352136
# 165 city name Chāndbāli | 1274761
# 166 city name Saint-Philippe | 935215
# 167 city name Bengkulu | 1649150
# 168 city name Pisco | 3932145
# 169 city name Sarny | 694792
# 170 city name Olinda | 3393536
# 171 city name Berlevåg | 780687
# 172 city name Tuatapere | 2180815
# 173 city name Leningradskiy | 2123814
# 174 city name Sineşti | 667043
# 175 city name Palmeira | 3455425
# 176 city name Leshukonskoye | 535839
# 177 city name Shāhpur | 1256722
# Data not Found:belushya guba
# 178 city name Khatanga | 2022572
# 179 city name Shimoda | 1852357
# 180 city name Corcoran | 5339539
# 181 city name Portland | 5746545
# 182 city name Kamiiso | 2129766
# 183 city name Saint Anthony | 5044290
# 184 city name Oksbøl | 2615859
# 185 city name Belmonte | 3470137
# 186 city name Palmer | 4946620
# 187 city name Iroquois Falls | 5984000
# 188 city name Rancho San Diego | 5386053
# Data not Found:cah ab
# Data not Found:phan rang
# 189 city name Punta Arenas | 3874787
# 190 city name Krasnosel'kup | 1502073
# 191 city name Katsuura | 2112309
# 192 city name Angoche | 1052944
# 193 city name La Roda | 2515555
# Data not Found:longlac
# 194 city name Kisangani | 212730
# 195 city name Alice Springs | 2077895
# Data not Found:bargal
# 196 city name Price | 5545269
# 197 city name Saint-Louis | 2246451
# 198 city name Nagato | 1899102
# 199 city name Alofi | 4036284
# 200 city name Lüderitz | 3355672
# 201 city name Bumba | 217745
# 202 city name Sitka | 5557293
# 203 city name Isangel | 2136825
# 204 city name Ilulissat | 3423146
# 205 city name Souillac | 933995
# 206 city name Yar-Sale | 1486321
# 207 city name Cilegon | 1627549
# Data not Found:vaitupu
# Data not Found:kawana waters
# 208 city name Dingle | 1714733
# 209 city name Arrondissement de Sens | 2975049
# 210 city name Caluquembe | 3351024
# 211 city name Faanui | 4034551
# 212 city name Jaisalmer | 1269507
# 213 city name Bulgan | 2032201
# 214 city name Avera | 4231997
# 215 city name Hailun | 2037069
# Data not Found:formoso do araguaia
# Data not Found:mys shmidta
# 216 city name Makakilo City | 5850554
# Data not Found:barentsburg
# 217 city name Mahébourg | 934322
# 218 city name Caraquet | 6942803
# 219 city name Bathsheba | 3374083
# 220 city name Krāslava | 458623
# 221 city name Longyearbyen | 2729907
# 222 city name Forsytheganj | 10722858
# 223 city name Salalah | 286621
# 224 city name Boguchany | 1509844
# 225 city name Castro | 3466704
# 226 city name Kichera | 2022129
# 227 city name Mafra | 3458147
# 228 city name Taguatinga | 6319623
# 229 city name Airai | 1651810
# 230 city name Mombetsu | 2129163
# 231 city name Constitución | 3893726
# 232 city name Paka | 1734313
# 233 city name Linqu | 1803364
# 234 city name Provideniya | 4031574
# 235 city name Kahului | 5847411
# 236 city name Syracuse | 2523082
# 237 city name Saldanha | 3361934
# 238 city name Nanortalik | 3421765
# 239 city name Beaverlodge | 5896969
# 240 city name Hamilton | 4513583
# Data not Found:bolungarvik
# 241 city name Port Moresby | 2088122
# 242 city name Byron Bay | 2172880
# 243 city name Xining | 1788852
# 244 city name Cidreira | 3466165
# 245 city name Mudanjiang | 2035715
# 246 city name Luang Prabang | 1655559
# 247 city name Santa Maria | 3450083
# 248 city name Champerico | 3598787
# 249 city name Khovd | 1516048
# 250 city name Koslan | 544084
# 251 city name Gazli | 1513990
# 252 city name Akçaabat | 752627
# 253 city name Andenes | 3163146
# 254 city name Makīnsk | 1521230
# 255 city name Flin Flon | 5954718
# 256 city name Fort-Shevchenko | 609906
# 257 city name Uauá | 3385883
# 258 city name Ouallam | 2440371
# 259 city name Banjar | 1650232
# 260 city name Karasjok | 779350
# 261 city name Ciudad Bolivar | 3645532
# Data not Found:tubruq
# 262 city name Mahibadhoo | 1337605
# 263 city name Saint-Augustin | 6137462
# Data not Found:attawapiskat
# 264 city name Thaba-Tseka | 1106835
# 265 city name Madaoua | 2441530
# 266 city name Sola | 2134814
# 267 city name Calabozo | 3647444
# 268 city name Margate | 2643044
# 269 city name Izumo | 1861084
# 270 city name Tura | 1254046
# 271 city name Weligama | 1223738
# 272 city name Meulaboh | 1214488
# 273 city name Port Lincoln | 2063036
# 274 city name Kandrian | 2094746
# 275 city name Qasigiannguit | 3420768
# 276 city name Porto Velho | 3662762
# 277 city name Laichow | 1804578
# 278 city name Novikovo | 487928
# 279 city name Taltal | 3870243
# 280 city name Upernavik | 3418910
# 281 city name Hobyo | 57000
# 282 city name Vuktyl | 470905
# 283 city name Mossamedes | 3347019
# 284 city name Zvishavane | 878549
# 285 city name Clyde River | 5924351
# 286 city name Bambanglipuro | 1650434
# 287 city name Jalu | 86049
# 288 city name Atambua | 1651103
# Data not Found:palabuhanratu
# 289 city name Santiago del Estero | 3835869
# 290 city name Laguna de Perlas | 3618522
# 291 city name Podyuga | 507899
# 292 city name Kieta | 2094027
# 293 city name Yangi Marg`ilon | 1513491
# 294 city name Esim | 2303611
# 295 city name Den Helder | 2757220
# 296 city name Horodok | 707752
# 297 city name Guerrero Negro | 4021858
# Data not Found:haibowan
# 298 city name Saint George | 5546220
# 299 city name Shenkursk | 494884
# 300 city name Abu Samrah | 172515
# 301 city name City of San Pedro | 1688781
# 302 city name Cherskiy | 2126199
# 303 city name Karanganyar | 1641320
# 304 city name Kruisfontein | 986717
# 305 city name Dilla | 338998
# 306 city name Uni | 478996
# Data not Found:borlange
# 307 city name Puerto Peñasco | 3991347
# 308 city name Mitsamiouli | 921786
# 309 city name Humboldt | 5565500
# Data not Found:toliary
# 310 city name Mackay | 2159220
# 311 city name Presidente Médici | 3924872
# 312 city name Del Rio | 5520076
# 313 city name Coquimbo | 3893629
# 314 city name Bireun | 1215350
# 315 city name Yulara | 6355222
# Data not Found:pilao arcado
# 316 city name Padang | 1633419
# 317 city name Daşoguz | 601734
# 318 city name Primero de Marzo | 3436812
# 319 city name Yaan | 2338660
# 320 city name Dutse | 2344245
# 321 city name Melfi | 3173615
# 322 city name Laguna | 5364271
# 323 city name Ostrovnoy | 556268
# 324 city name Moshupa | 933018
# 325 city name El Salvador | 3585968
# 326 city name Toora-Khem | 1489401
# 327 city name Tra Vinh | 1563926
# 328 city name Port Hawkesbury | 6111867
# 329 city name Ko Samui | 1154689
# 330 city name Koumac | 2140558
# 331 city name Norman Wells | 6089245
# 332 city name Soyo | 2236967
# 333 city name Basco | 1726449
# 334 city name Puerto Carreño | 3671519
# 335 city name Enid | 4535961
# 336 city name Port Hedland | 2063042
# 337 city name Pringsewu | 1630639
# 338 city name Vostok | 2013279
# 339 city name San Miguel de Cozumel | 3530103
# 340 city name Cascais | 2269594
# 341 city name Dickinson | 4686163
# 342 city name Hofn | 2630299
# 343 city name Fengzhen | 2037391
# 344 city name Kununurra | 2068110
# 345 city name Heraclea | 315498
# 346 city name Seoul | 1835848
# 347 city name Saint-Joseph | 6690296
# 348 city name Ancud | 3899695
# 349 city name Geraldton | 2070998
# 350 city name Bow Island | 5906757
# 351 city name Balyqshy | 610445
# 352 city name San Jerónimo | 3929611
# 353 city name Eilenburg | 2931871
# 354 city name Wajir | 178443
# 355 city name Alyangula | 2079582
# 356 city name Uddevalla | 2666670
# 357 city name Zarinsk | 1485439
# 358 city name Port Blair | 1259385
# 359 city name Faya | 110690
# 360 city name Richards Bay | 962367
# 361 city name Roald | 3141667
# 362 city name North Bend | 5742974
# 363 city name Jardim | 3460087
# 364 city name Chui | 3443061
# 365 city name Aklavik | 5882953
# 366 city name Imbituba | 3461370
# 367 city name Nioro | 2412408
# 368 city name Viedma | 3832899
# 369 city name Buala | 2109528
# 370 city name Waverly | 5014208
# 371 city name Magdalena | 1703912
# 372 city name Benin | 2395170
# 373 city name Huarmey | 3939168
# 374 city name Te Anau | 2181625
# 375 city name Jacareacanga | 3397763
# 376 city name Lakes Entrance | 2160735
# 377 city name Avezzano | 3182636
# 378 city name Reconquista | 3429594
# 379 city name Pakxan | 1655140
# 380 city name Umm Kaddadah | 364933
# 381 city name Prince Albert | 6113335
# 382 city name Carballo | 3126369
# 383 city name Lewistown | 5197850
# 384 city name Broken Hill | 2173911
# 385 city name Takoradze | 2294915
# Data not Found:sinkat
# 386 city name Baikunthpur | 1277769
# Data not Found:chagda
# 387 city name Cairns | 2172797
# 388 city name Finschhafen | 2097418
# 389 city name Kātrās | 1267439
# 390 city name Bucerías | 4016734
# 391 city name Flinders | 6255012
# 392 city name Maniitsoq | 3421982
# Data not Found:ruatoria
# 393 city name Okhotsk | 2122605
# 394 city name Dubbo | 2168305
# 395 city name Ixtapa | 4004293
# 396 city name Warrnambool | 2144528
# 397 city name Zelenoborskiy | 463838
# 398 city name Mayo | 4362001
# 399 city name Sal Rei | 3374235
# 400 city name Hangu | 1808931
# 401 city name Khani | 610864
# 402 city name Ojinaga | 3994469
# Data not Found:marcona
# Data not Found:yingzhong
# 403 city name Mareeba | 2158767
# 404 city name Sioux Lookout | 6148373
# Data not Found:ngukurr
# 405 city name Kyabé | 2429344
# 406 city name Lagoa | 3372964
# 407 city name Culiacán | 4012176
# 408 city name Saint-François | 2980080
# 409 city name Zakamensk | 2012728
# 410 city name Hanyang | 1798537
# 411 city name Lianhe | 2035669
# 412 city name Marsh Harbour | 3571913
# 413 city name Phuket | 1151253
# 414 city name Asău | 686090
# 415 city name Adrar | 2381972
# 416 city name Almaznyy | 582447
# Data not Found:acutzilapan
# 417 city name Totness | 3382867
# 418 city name Yermolayevo | 467246
# 419 city name San Cristobal | 3628473
# 420 city name Nambucca Heads | 2155858
# 421 city name Half Moon Bay | 5354943
# 422 city name Mangan | 1263776
# 423 city name Nelson Bay | 2155562
# 424 city name The Hammocks | 4175117
# 425 city name Genhe | 2037252
# 426 city name Fortuna | 5563839
# 427 city name Nichinan | 1855476
# 428 city name Niamey | 2440485
# Data not Found:kamenskoye
# 429 city name Jiayuguan City | 1280957
# 430 city name Moanda | 2398269
# 431 city name Kogon | 1217180
# 432 city name Ishikari | 2129909
# 433 city name Malé | 1282027
# 434 city name Coyhaique | 3894426
# 435 city name Chicama | 3698359
# 436 city name Urla | 298316
# 437 city name Zemio | 235826
# 438 city name Nuevo Ideal | 3994607
# 439 city name Morón | 3430545
# 440 city name Kidal | 2455290
# 441 city name Hongjiang | 1808106
# 442 city name Bethel | 5282297
# 443 city name Namwala | 901766
# 444 city name Khakhea | 933649
# 445 city name Sambava | 1056899
# 446 city name Svolvær | 3135020
# 447 city name Touros | 3386213
# 448 city name Russellville | 4129397
# 449 city name Vite | 1253091
# 450 city name Honningsvåg | 779554
# 451 city name Codrington | 2171099
# 452 city name Pecos | 5528182
# 453 city name Jieshi | 1805857
# 454 city name Yurga | 1485724
# 455 city name Acapulco de Juárez | 3533462
# 456 city name Prainha | 3391287
# Data not Found:aporawan
# 457 city name Esil | 1524296
# 458 city name Krasnoarmeysk | 542464
# 459 city name Severnoye | 1492607
# 460 city name Bismarck | 5688025
# 461 city name Sijunjung | 1627185
# 462 city name Lebyazh'ye | 1500764
# 463 city name Caconda | 3351380
# 464 city name Vilkaviškis | 593153
# 465 city name Baffa | 1184020
# 466 city name Port-Cartier | 6111696
# 467 city name Tanete | 1629965
# 468 city name Langarūd | 125897
# 469 city name Guadalupe y Calvo | 4005370
# 470 city name Gemena | 2315728
# 471 city name Ust-Tsilma | 477940
# 472 city name Otane | 2185329
# 473 city name Niquelândia | 3456285
# 474 city name ‘Āhuimanu | 5856516
# 475 city name Kargasok | 1504382
# 476 city name Sibolga | 1213855
# 477 city name San Ramon | 5392593
# 478 city name Vanimo | 2084442
# 479 city name Gundsømagle | 2620997
# Data not Found:sentyabrskiy
# 480 city name Panjakent | 1220798
# 481 city name Santa Cruz de la Sierra | 3904906
# 482 city name Feldkirchen | 6556310
# 483 city name Avrillé | 3035612
# 484 city name Kirakira | 2178753
# Data not Found:nikolskoye-na-cheremshane
# 485 city name Marihatag | 1700933
# 486 city name Cooma | 2170577
# 487 city name Los Aquijes | 3935969
# 488 city name Eyrarbakki | 3413604
# 489 city name Maningrida | 2067089
# 490 city name Mokhsogollokh | 2019867
# 491 city name Ust'-Omchug | 2120047
# 492 city name Jiangyan | 1806218
# 493 city name Gal'bshtadt | 1497899
# 494 city name Polyarny | 506763
# 495 city name Port Maria | 3488985
# 496 city name Murupara | 2186338
# 497 city name Buin | 3897774
# 498 city name Denizli Province | 317106
# 499 city name Umluj | 100926
# 500 city name Bristol | 4931378
# 501 city name Tigre | 3427761
# 502 city name Caculé | 3468349
# Data not Found:portpatrick
# Data not Found:tungkang
# 503 city name Tambura | 366444
# 504 city name Ust-Kuyga | 2013921
# 505 city name Mīrābād | 1133310
# 506 city name Husavik | 2629833
# 507 city name Kalmunai | 1242110
# 508 city name Sørland | 3137469
# 509 city name Kuching | 1735634
# 510 city name Bam | 141736
# 511 city name Srednekolymsk | 2121025
# 512 city name Rome | 5134295
# 513 city name Puerto Escondido | 3520994
# 514 city name Cayenne | 3382160
# 515 city name Beringovskiy | 2126710
# 516 city name Alta Floresta | 6316343
# Data not Found:cucer
# 517 city name Kitimat | 5993072
# 518 city name San Lorenzo | 3437056
# 519 city name Mersing | 1732826
# 520 city name Daru | 2098329
# 521 city name Magistral'nyy | 2020584
# 522 city name Jutaí | 3663693
# 523 city name Jacqueville | 2287778
# 524 city name Qaqortoq | 3420846
# 525 city name Santa Vitória do Palmar | 3449747
# 526 city name Aswān | 359792
# 527 city name Ajdabiya | 89113
# 528 city name Baykit | 1510689
# 529 city name Straumen | 3135728
# 530 city name Swan Hill | 2147756
# 531 city name Pacific Grove | 5380437
# 532 city name Lhokseumawe | 1214658
# 533 city name Shestakovo | 2016733
# 534 city name Nanzhang | 1799574
# 535 city name Jiuquan | 1279945
# 536 city name Guerrero | 3527213
# 537 city name Zhicheng | 1784554
# 538 city name Oshawa | 6094578
# 539 city name Mount Darwin | 885800
# 540 city name Sengiley | 497094
# 541 city name Río Gallegos | 3838859
# 542 city name Paamiut | 3421193
# 543 city name Russell | 4047434
# 544 city name Solnechnyy | 2016307
# 545 city name Qeshm | 119374
# 546 city name Vila Velha | 3445026
# 547 city name Sakakah | 102527
# 548 city name Boké | 2422924
# 549 city name Hammerfest | 779683
# 550 city name Bubaque | 2374583
# 551 city name Alenquer | 3407980
# 552 city name Ranong | 1150965
# 553 city name Pueblo | 5435464
# Data not Found:temaraia
# 554 city name Wanning | 1791779
# 555 city name Keti Bandar | 1174451
# Data not Found:ozgon
# 556 city name Kupino | 1501365
# 557 city name Purranque | 3874579
# 558 city name Verkhnevilyuysk | 2013639
# 559 city name Ekhabi | 2122614
# 560 city name Emerald | 2167426
# Data not Found:samalaeulu
# 561 city name Kedrovyy | 1538641
# 562 city name Vasil'yevskiy Mokh | 476548
# Data not Found:hihifo
# 563 city name Escárcega | 3527795
# 564 city name Rawson | 3839307
# 565 city name São João da Barra | 3448903
# 566 city name Baruun-Urt | 2032614
# 567 city name Aripuanã | 3665202
# 568 city name Astoria | 5711847
# 569 city name Cláudio | 3466062
# 570 city name Gazojak | 1514792
# 571 city name Necochea | 3430443
# 572 city name Batangafo | 2389691
# 573 city name Denham Springs | 4321988
# 574 city name Opuwo | 3354077
# 575 city name Tessalit | 2449893
# 576 city name Cape Canaveral | 4149959
# 577 city name Bintulu | 1737486
# 578 city name Chalmette | 4319518
# 579 city name Kangaatsiaq | 3422683
# 580 city name Zambezi | 895953
# 581 city name Karur | 1267648
# 582 city name Quatre Cocos | 1106643
# 583 city name La Estancia | 4002462
# 584 city name Zalari | 2012702
# 585 city name Ippy | 238566
# 586 city name Newport | 2641598
# 587 city name Westerland | 2810284
# 588 city name Cambrils | 3126888
# 589 city name Labuan | 1733782
# 590 city name Grand Gaube | 934479
# 591 city name Mariehamn | 3041732
# 592 city name Kondinskoye | 1502697
# 593 city name Chabahar | 1161724
# 594 city name Ambovombe | 1079048
# 595 city name Lethem | 3379316
# Data not Found:barawe
# 596 city name Rockport | 4723422
# 597 city name Severo-Yeniseyskiy | 1492566
# 598 city name Níjar | 2513222
# 599 city name San Quintín | 3984997
# 600 city name Pacifica | 5380420
# 601 city name Okha | 2122614
# 602 city name Olafsvik | 3414079
# 603 city name Jiwani | 1175712
# 604 city name Elwood | 7932620
# 605 city name Rantepao | 1629974
# 606 city name Lobito | 3347939
# 607 city name Bafoulabé | 2460755
# 608 city name Province of Mantua | 3174050
# 609 city name Nerchinskiy Zavod | 2019323
# 610 city name Marsá Maţrūḩ | 352733
# 611 city name Saint-Pierre | 935214
# 612 city name Vanavara | 2013727
# 613 city name Chiapilla | 3531010
# 614 city name Burnie | 2173125
# 615 city name Kaduqli | 373141
# 616 city name Conneaut | 5150986
# 617 city name Cabatuan | 1721720
# 618 city name Karlskrona | 2701713
# Data not Found:banovce
# 619 city name Bakchar | 1511057
# 620 city name Manggar | 1636426
# 621 city name El Vigia | 3641099
# 622 city name College | 5859699
# 623 city name Potsdam | 2852458
# 624 city name Sudova Vyshnya | 692301
# 625 city name Egvekinot | 4031742
# 626 city name Bambous Virieux | 1106677
# 627 city name Waipawa | 2206874
# 628 city name Nuevo Progreso | 3522526
# 629 city name Witu | 178093
# 630 city name High Level | 5975004
# 631 city name Moyale | 186180
# 632 city name Bestöbe | 1525376
# 633 city name Manokwari | 1636308
# 634 city name Baghmara | 1274553
# 635 city name Kyzyl-Suu | 1527497
# 636 city name Rock Sound | 3571592
# 637 city name Marzuq | 72181
# 638 city name Ishigaki | 1861416
# 639 city name Bugene | 161022
# 640 city name Varhaug | 3132644
# 641 city name Damāvand | 138042
# 642 city name Biak | 1637001
# 643 city name Stephenville | 4734350
# 644 city name Dudinka | 1507116
# 645 city name Naze | 1855540
# 646 city name Wonosobo | 1621395
# 647 city name La Palma | 5364022
# 648 city name Mil'kovo | 2123278
# 649 city name Beyneu | 610298
# 650 city name Sobolevo | 525426
# 651 city name Arrondissement de Millau | 2993874
# 652 city name Svetlaya | 2015852
# 653 city name Zhangaözen | 607610
# 654 city name Bom Despacho | 3469516
# 655 city name Vitim | 2013375
# 656 city name Borovskoy | 1525121
# 657 city name Mount Isa | 2065594
# 658 city name Prachatice | 3067713
# 659 city name Batagay | 2027044
# 660 city name Wundanyi | 178073
# 661 city name Brumado | 3468893
# 662 city name Barranca | 3946820
# 663 city name Xucheng | 1787837
# 664 city name Hambantota | 1244926
# 665 city name Berkakit | 2026777
# 666 city name Don Luan | 1582436
# 667 city name Jerantut | 1732602
# 668 city name Pochutla | 3517970
# 669 city name Bontang | 1648186
# 670 city name Moncton | 6076211
# 671 city name Nizwá | 286987
# 672 city name Ellensburg | 5793639
# 673 city name Marshfield | 5261969
# 674 city name Vidim | 2013406
# 675 city name Villazón | 3901501
# 676 city name Szany | 3044909
# 677 city name Batagay-Alyta | 2027042
# 678 city name Denpasar | 1645528
# 679 city name Bilibino | 2126682
# 680 city name Bara | 2347758
# Data not Found:burica
# 681 city name Saint Lawrence | 2562619
# 682 city name Kiryat Gat | 293842
# 683 city name Chunskiy | 1507636
# 684 city name Adelaide | 2078025
# 685 city name Krasne | 704277
# 686 city name Moose Factory | 6078372
# 687 city name Petropavlovsk-Kamchatskiy | 2122104
# 688 city name Praia | 3374333
# 689 city name Birao | 240210
# 690 city name Gōtsuchō | 1863521
# 691 city name Praia da Vitória | 3372760
# Data not Found:kuche
# 692 city name Salé | 2537763
# 693 city name Central Point | 5718601
# Data not Found:meyungs
# Data not Found:kapustin yar-1
# 694 city name Zverinogolovskoye | 1484943
# 695 city name Semnan | 116402
# 696 city name Bogandinskiy | 1509902
# 697 city name Aykhal | 2027296
# Data not Found:tabiauea
# 698 city name Chifeng | 2038067
# 699 city name Ca Mau | 1586443
# Data not Found:tumannyy
# 700 city name Chingirlau | 610091
# Data not Found:ahumada
# 701 city name Nampula | 1033356
# 702 city name Gambo | 239300
# 703 city name Taunggyi | 1293960
# [{'City': 'Coahuayana Viejo',
#   'Lat': 18.7333,
#   'Lon': -103.6833,
#   'Max_temp': 89.35,
#   'Humidity': 54,
#   'Clouds': 79,
#   'Wind Speed': 6.73,
#   'Country': 'MX',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lon': 168.3333,
#   'Max_temp': 49.8,
#   'Humidity': 80,
#   'Clouds': 61,
#   'Wind Speed': 8.32,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tual',
#   'Lat': -5.6667,
#   'Lon': 132.75,
#   'Max_temp': 81.27,
#   'Humidity': 78,
#   'Clouds': 100,
#   'Wind Speed': 14.43,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pangai',
#   'Lat': -19.8,
#   'Lon': -174.35,
#   'Max_temp': 80.71,
#   'Humidity': 65,
#   'Clouds': 20,
#   'Wind Speed': 6.91,
#   'Country': 'TO',
#   'Current Description': 'few clouds'},
#  {'City': 'Dabat',
#   'Lat': 12.9842,
#   'Lon': 37.765,
#   'Max_temp': 62.71,
#   'Humidity': 33,
#   'Clouds': 96,
#   'Wind Speed': 5.26,
#   'Country': 'ET',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lon': 73.0833,
#   'Max_temp': 82.74,
#   'Humidity': 73,
#   'Clouds': 11,
#   'Wind Speed': 12.35,
#   'Country': 'MV',
#   'Current Description': 'few clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lon': -156.7887,
#   'Max_temp': 32.02,
#   'Humidity': 86,
#   'Clouds': 90,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Current Description': 'mist'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lon': -90.3518,
#   'Max_temp': 80.56,
#   'Humidity': 90,
#   'Clouds': 38,
#   'Wind Speed': 1.99,
#   'Country': 'EC',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lon': 20.0403,
#   'Max_temp': 57.27,
#   'Humidity': 47,
#   'Clouds': 4,
#   'Wind Speed': 6.62,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Huai Mek',
#   'Lat': 16.5898,
#   'Lon': 103.2355,
#   'Max_temp': 79,
#   'Humidity': 99,
#   'Clouds': 100,
#   'Wind Speed': 5.32,
#   'Country': 'TH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lon': -130.3201,
#   'Max_temp': 51.89,
#   'Humidity': 78,
#   'Clouds': 90,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Current Description': 'light rain'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lon': -149.15,
#   'Max_temp': 86.02,
#   'Humidity': 73,
#   'Clouds': 45,
#   'Wind Speed': 12.39,
#   'Country': 'PF',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lon': -159.319,
#   'Max_temp': 83.19,
#   'Humidity': 70,
#   'Clouds': 20,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Ketchikan',
#   'Lat': 55.3422,
#   'Lon': -131.6461,
#   'Max_temp': 53.58,
#   'Humidity': 89,
#   'Clouds': 100,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'San Policarpo',
#   'Lat': 12.1791,
#   'Lon': 125.5072,
#   'Max_temp': 79.14,
#   'Humidity': 86,
#   'Clouds': 100,
#   'Wind Speed': 3.8,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lon': -68.3,
#   'Max_temp': 44.26,
#   'Humidity': 57,
#   'Clouds': 40,
#   'Wind Speed': 12.66,
#   'Country': 'AR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Los Llanos de Aridane',
#   'Lat': 28.6585,
#   'Lon': -17.9182,
#   'Max_temp': 64.15,
#   'Humidity': 82,
#   'Clouds': 90,
#   'Wind Speed': 12.53,
#   'Country': 'ES',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saravan',
#   'Lat': 39.7196,
#   'Lon': 45.6483,
#   'Max_temp': 57.85,
#   'Humidity': 52,
#   'Clouds': 0,
#   'Wind Speed': 4.65,
#   'Country': 'AM',
#   'Current Description': 'clear sky'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lon': 140.8333,
#   'Max_temp': 72.28,
#   'Humidity': 83,
#   'Clouds': 100,
#   'Wind Speed': 1.12,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lon': -134.9692,
#   'Max_temp': 76.77,
#   'Humidity': 83,
#   'Clouds': 98,
#   'Wind Speed': 15.23,
#   'Country': 'PF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lon': 27.9116,
#   'Max_temp': 62.28,
#   'Humidity': 39,
#   'Clouds': 0,
#   'Wind Speed': 9.24,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lon': -139.0333,
#   'Max_temp': 80.19,
#   'Humidity': 62,
#   'Clouds': 61,
#   'Wind Speed': 6.73,
#   'Country': 'PF',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kwang Binh',
#   'Lat': 17.4833,
#   'Lon': 106.6,
#   'Max_temp': 82.81,
#   'Humidity': 75,
#   'Clouds': 100,
#   'Wind Speed': 7.45,
#   'Country': 'VN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lon': -28.7,
#   'Max_temp': 65.16,
#   'Humidity': 87,
#   'Clouds': 100,
#   'Wind Speed': 7.65,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Klaksvík',
#   'Lat': 62.2266,
#   'Lon': -6.589,
#   'Max_temp': 49.12,
#   'Humidity': 99,
#   'Clouds': 100,
#   'Wind Speed': 15.57,
#   'Country': 'FO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wasilla',
#   'Lat': 61.5814,
#   'Lon': -149.4394,
#   'Max_temp': 73.65,
#   'Humidity': 48,
#   'Clouds': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lon': -165.4064,
#   'Max_temp': 36.16,
#   'Humidity': 83,
#   'Clouds': 100,
#   'Wind Speed': 4.79,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lon': -79.2353,
#   'Max_temp': 82.29,
#   'Humidity': 50,
#   'Clouds': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lon': 172.7902,
#   'Max_temp': 82.58,
#   'Humidity': 72,
#   'Clouds': 12,
#   'Wind Speed': 8.48,
#   'Country': 'KI',
#   'Current Description': 'light rain'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lon': 121.9,
#   'Max_temp': 57.04,
#   'Humidity': 61,
#   'Clouds': 100,
#   'Wind Speed': 27.4,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lon': 150.1833,
#   'Max_temp': 54.91,
#   'Humidity': 69,
#   'Clouds': 100,
#   'Wind Speed': 4.18,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Siniscola',
#   'Lat': 40.5719,
#   'Lon': 9.6922,
#   'Max_temp': 65.75,
#   'Humidity': 85,
#   'Clouds': 27,
#   'Wind Speed': 4.81,
#   'Country': 'IT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lon': 42.7678,
#   'Max_temp': 53.85,
#   'Humidity': 94,
#   'Clouds': 60,
#   'Wind Speed': 6.53,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Merke',
#   'Lat': 42.8728,
#   'Lon': 73.1786,
#   'Max_temp': 69.96,
#   'Humidity': 53,
#   'Clouds': 100,
#   'Wind Speed': 6.02,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lon': -37.6368,
#   'Max_temp': 39.29,
#   'Humidity': 91,
#   'Clouds': 98,
#   'Wind Speed': 5.23,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salinópolis',
#   'Lat': -0.6136,
#   'Lon': -47.3561,
#   'Max_temp': 77.79,
#   'Humidity': 86,
#   'Clouds': 37,
#   'Wind Speed': 9.42,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lon': 170.3133,
#   'Max_temp': 48.31,
#   'Humidity': 66,
#   'Clouds': 29,
#   'Wind Speed': 13.11,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lon': -122.7002,
#   'Max_temp': 60.39,
#   'Humidity': 41,
#   'Clouds': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Khor',
#   'Lat': 47.8861,
#   'Lon': 134.9464,
#   'Max_temp': 61.86,
#   'Humidity': 74,
#   'Clouds': 68,
#   'Wind Speed': 11.77,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kosino',
#   'Lat': 58.4127,
#   'Lon': 51.2782,
#   'Max_temp': 53.83,
#   'Humidity': 77,
#   'Clouds': 5,
#   'Wind Speed': 3.56,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Vardø',
#   'Lat': 70.3705,
#   'Lon': 31.1107,
#   'Max_temp': 39.15,
#   'Humidity': 74,
#   'Clouds': 6,
#   'Wind Speed': 1.88,
#   'Country': 'NO',
#   'Current Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lon': -175.2,
#   'Max_temp': 77.16,
#   'Humidity': 78,
#   'Clouds': 75,
#   'Wind Speed': 13.8,
#   'Country': 'TO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pathein',
#   'Lat': 16.7833,
#   'Lon': 94.7333,
#   'Max_temp': 82.92,
#   'Humidity': 77,
#   'Clouds': 96,
#   'Wind Speed': 8.84,
#   'Country': 'MM',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sokółka',
#   'Lat': 53.4072,
#   'Lon': 23.5023,
#   'Max_temp': 57.65,
#   'Humidity': 90,
#   'Clouds': 1,
#   'Wind Speed': 6.69,
#   'Country': 'PL',
#   'Current Description': 'clear sky'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lon': -73.65,
#   'Max_temp': 48.79,
#   'Humidity': 79,
#   'Clouds': 91,
#   'Wind Speed': 4.21,
#   'Country': 'CL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lon': 115.3333,
#   'Max_temp': 46.09,
#   'Humidity': 78,
#   'Clouds': 0,
#   'Wind Speed': 7.83,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lon': 18.4232,
#   'Max_temp': 72.01,
#   'Humidity': 27,
#   'Clouds': 0,
#   'Wind Speed': 13.22,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lon': -159.775,
#   'Max_temp': 77.05,
#   'Humidity': 61,
#   'Clouds': 75,
#   'Wind Speed': 3.44,
#   'Country': 'CK',
#   'Current Description': 'broken clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lon': -109.9124,
#   'Max_temp': 100.51,
#   'Humidity': 52,
#   'Clouds': 7,
#   'Wind Speed': 10.45,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': "Chul'man",
#   'Lat': 56.8479,
#   'Lon': 124.9104,
#   'Max_temp': 67.84,
#   'Humidity': 52,
#   'Clouds': 47,
#   'Wind Speed': 9.86,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hauterive',
#   'Lat': 46.0901,
#   'Lon': 3.4459,
#   'Max_temp': 59.76,
#   'Humidity': 96,
#   'Clouds': 81,
#   'Wind Speed': 2.3,
#   'Country': 'FR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lima',
#   'Lat': -12.0432,
#   'Lon': -77.0282,
#   'Max_temp': 64.65,
#   'Humidity': 80,
#   'Clouds': 90,
#   'Wind Speed': 6.91,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lon': -68.5145,
#   'Max_temp': 33.53,
#   'Humidity': 93,
#   'Clouds': 75,
#   'Wind Speed': 5.01,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Erzincan Province',
#   'Lat': 39.75,
#   'Lon': 39.5,
#   'Max_temp': 49.14,
#   'Humidity': 76,
#   'Clouds': 0,
#   'Wind Speed': 4.12,
#   'Country': 'TR',
#   'Current Description': 'clear sky'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lon': -39.9167,
#   'Max_temp': 77.4,
#   'Humidity': 86,
#   'Clouds': 26,
#   'Wind Speed': 8.16,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lon': -73.9662,
#   'Max_temp': 86.58,
#   'Humidity': 61,
#   'Clouds': 46,
#   'Wind Speed': 5.03,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lon': -52.7314,
#   'Max_temp': 45.28,
#   'Humidity': 88,
#   'Clouds': 75,
#   'Wind Speed': 17.27,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mabaruma',
#   'Lat': 8.2,
#   'Lon': -59.7833,
#   'Max_temp': 74.7,
#   'Humidity': 95,
#   'Clouds': 72,
#   'Wind Speed': 5.14,
#   'Country': 'GY',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lon': 168.8643,
#   'Max_temp': 49.48,
#   'Humidity': 77,
#   'Clouds': 59,
#   'Wind Speed': 3.38,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint Paul Harbor',
#   'Lat': 57.79,
#   'Lon': -152.4072,
#   'Max_temp': 55.89,
#   'Humidity': 52,
#   'Clouds': 12,
#   'Wind Speed': 6.13,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Fukuechō',
#   'Lat': 32.6881,
#   'Lon': 128.8419,
#   'Max_temp': 70.12,
#   'Humidity': 77,
#   'Clouds': 100,
#   'Wind Speed': 6.31,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Caiapônia',
#   'Lat': -16.9567,
#   'Lon': -51.8103,
#   'Max_temp': 69.28,
#   'Humidity': 56,
#   'Clouds': 98,
#   'Wind Speed': 1.66,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Abnūb',
#   'Lat': 27.2696,
#   'Lon': 31.1511,
#   'Max_temp': 75.42,
#   'Humidity': 36,
#   'Clouds': 18,
#   'Wind Speed': 17.94,
#   'Country': 'EG',
#   'Current Description': 'few clouds'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lon': 134.2556,
#   'Max_temp': 77.5,
#   'Humidity': 81,
#   'Clouds': 100,
#   'Wind Speed': 7.02,
#   'Country': 'PW',
#   'Current Description': 'moderate rain'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lon': 95.3222,
#   'Max_temp': 79.2,
#   'Humidity': 73,
#   'Clouds': 100,
#   'Wind Speed': 13.47,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lon': 128.8694,
#   'Max_temp': 43.83,
#   'Humidity': 64,
#   'Clouds': 100,
#   'Wind Speed': 1.54,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lon': -22.4338,
#   'Max_temp': 48.67,
#   'Humidity': 93,
#   'Clouds': 75,
#   'Wind Speed': 15.55,
#   'Country': 'IS',
#   'Current Description': 'broken clouds'},
#  {'City': 'Arraial do Cabo',
#   'Lat': -22.9661,
#   'Lon': -42.0278,
#   'Max_temp': 73.36,
#   'Humidity': 94,
#   'Clouds': 75,
#   'Wind Speed': 20.47,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lon': 19.2345,
#   'Max_temp': 66.9,
#   'Humidity': 44,
#   'Clouds': 1,
#   'Wind Speed': 11.43,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lon': 140.7667,
#   'Max_temp': 55.31,
#   'Humidity': 71,
#   'Clouds': 100,
#   'Wind Speed': 18.41,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bereda',
#   'Lat': 43.2686,
#   'Lon': -7.5406,
#   'Max_temp': 55.92,
#   'Humidity': 100,
#   'Clouds': 70,
#   'Wind Speed': 3.47,
#   'Country': 'ES',
#   'Current Description': 'broken clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lon': -69.3632,
#   'Max_temp': 40.37,
#   'Humidity': 76,
#   'Clouds': 59,
#   'Wind Speed': 5.39,
#   'Country': 'GL',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lon': 147.2712,
#   'Max_temp': 82.85,
#   'Humidity': 70,
#   'Clouds': 90,
#   'Wind Speed': 5.91,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Udachny',
#   'Lat': 66.4167,
#   'Lon': 112.4,
#   'Max_temp': 43.39,
#   'Humidity': 63,
#   'Clouds': 82,
#   'Wind Speed': 23.38,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Aksu',
#   'Lat': 41.1231,
#   'Lon': 80.2644,
#   'Max_temp': 72.86,
#   'Humidity': 29,
#   'Clouds': 47,
#   'Wind Speed': 5.64,
#   'Country': 'CN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Merauke',
#   'Lat': -8.4667,
#   'Lon': 140.3333,
#   'Max_temp': 76.5,
#   'Humidity': 90,
#   'Clouds': 99,
#   'Wind Speed': 13.65,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khuzdar',
#   'Lat': 27.7384,
#   'Lon': 66.6434,
#   'Max_temp': 77.49,
#   'Humidity': 51,
#   'Clouds': 0,
#   'Wind Speed': 3.69,
#   'Country': 'PK',
#   'Current Description': 'clear sky'},
#  {'City': 'Vestmanna',
#   'Lat': 62.1564,
#   'Lon': -7.1664,
#   'Max_temp': 47.32,
#   'Humidity': 100,
#   'Clouds': 90,
#   'Wind Speed': 9.35,
#   'Country': 'FO',
#   'Current Description': 'drizzle'},
#  {'City': 'San Jose',
#   'Lat': 37.3394,
#   'Lon': -121.895,
#   'Max_temp': 85.77,
#   'Humidity': 37,
#   'Clouds': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Vila Franca do Campo',
#   'Lat': 37.7167,
#   'Lon': -25.4333,
#   'Max_temp': 64.81,
#   'Humidity': 86,
#   'Clouds': 100,
#   'Wind Speed': 1.83,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Berbera',
#   'Lat': 10.4396,
#   'Lon': 45.0143,
#   'Max_temp': 91.31,
#   'Humidity': 46,
#   'Clouds': 0,
#   'Wind Speed': 10.96,
#   'Country': 'SO',
#   'Current Description': 'clear sky'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lon': -120.4579,
#   'Max_temp': 76.01,
#   'Humidity': 73,
#   'Clouds': 90,
#   'Wind Speed': 8.99,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lon': 113.6333,
#   'Max_temp': 60.87,
#   'Humidity': 67,
#   'Clouds': 90,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lon': -97.8558,
#   'Max_temp': 60.96,
#   'Humidity': 77,
#   'Clouds': 90,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lon': -46.05,
#   'Max_temp': 46.04,
#   'Humidity': 66,
#   'Clouds': 100,
#   'Wind Speed': 3.4,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lon': -70.4,
#   'Max_temp': 60.08,
#   'Humidity': 83,
#   'Clouds': 33,
#   'Wind Speed': 6.76,
#   'Country': 'CL',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Lon': 124.2928,
#   'Max_temp': 64.65,
#   'Humidity': 86,
#   'Clouds': 99,
#   'Wind Speed': 1.9,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lon': -65.7125,
#   'Max_temp': 32.49,
#   'Humidity': 93,
#   'Clouds': 26,
#   'Wind Speed': 2.86,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ulladulla',
#   'Lat': -35.35,
#   'Lon': 150.4667,
#   'Max_temp': 58.87,
#   'Humidity': 69,
#   'Clouds': 100,
#   'Wind Speed': 5.84,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lon': 114.0833,
#   'Max_temp': 39.24,
#   'Humidity': 56,
#   'Clouds': 77,
#   'Wind Speed': 4.59,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Arrondissement du Havre',
#   'Lat': 49.5833,
#   'Lon': 0.3333,
#   'Max_temp': 54.45,
#   'Humidity': 94,
#   'Clouds': 0,
#   'Wind Speed': 2.04,
#   'Country': 'FR',
#   'Current Description': 'clear sky'},
#  {'City': 'Yacuiba',
#   'Lat': -22.038,
#   'Lon': -63.6797,
#   'Max_temp': 59.7,
#   'Humidity': 91,
#   'Clouds': 97,
#   'Wind Speed': 2.15,
#   'Country': 'BO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sisimiut',
#   'Lat': 66.9395,
#   'Lon': -53.6735,
#   'Max_temp': 42.8,
#   'Humidity': 83,
#   'Clouds': 100,
#   'Wind Speed': 3.15,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lon': 147.0587,
#   'Max_temp': 56.91,
#   'Humidity': 78,
#   'Clouds': 100,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Current Description': 'light rain'},
#  {'City': 'Karratha',
#   'Lat': -20.7377,
#   'Lon': 116.8463,
#   'Max_temp': 74.23,
#   'Humidity': 58,
#   'Clouds': 76,
#   'Wind Speed': 9.55,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lon': 26.891,
#   'Max_temp': 64.06,
#   'Humidity': 35,
#   'Clouds': 0,
#   'Wind Speed': 8.34,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Kiama',
#   'Lat': -34.6833,
#   'Lon': 150.8667,
#   'Max_temp': 59.25,
#   'Humidity': 69,
#   'Clouds': 89,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lon': -151.0167,
#   'Max_temp': 80.69,
#   'Humidity': 73,
#   'Clouds': 49,
#   'Wind Speed': 9.66,
#   'Country': 'PF',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lon': 88.3972,
#   'Max_temp': 31.59,
#   'Humidity': 97,
#   'Clouds': 100,
#   'Wind Speed': 5.21,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': "Severo-Kuril'sk",
#   'Lat': 50.6789,
#   'Lon': 156.125,
#   'Max_temp': 43,
#   'Humidity': 93,
#   'Clouds': 100,
#   'Wind Speed': 10.89,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kamaishi',
#   'Lat': 39.2667,
#   'Lon': 141.8833,
#   'Max_temp': 68.95,
#   'Humidity': 63,
#   'Clouds': 100,
#   'Wind Speed': 4.56,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lon': 170.5036,
#   'Max_temp': 52.81,
#   'Humidity': 72,
#   'Clouds': 97,
#   'Wind Speed': 5.99,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Deputatsky',
#   'Lat': 69.3,
#   'Lon': 139.9,
#   'Max_temp': 43.63,
#   'Humidity': 57,
#   'Clouds': 7,
#   'Wind Speed': 4.68,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Chillicothe',
#   'Lat': 39.3331,
#   'Lon': -82.9824,
#   'Max_temp': 84.69,
#   'Humidity': 51,
#   'Clouds': 1,
#   'Wind Speed': 7.87,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Dolinsk',
#   'Lat': 47.35,
#   'Lon': 142.8,
#   'Max_temp': 60.66,
#   'Humidity': 67,
#   'Clouds': 8,
#   'Wind Speed': 4.25,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': "Tegul'det",
#   'Lat': 57.3064,
#   'Lon': 88.1667,
#   'Max_temp': 54.84,
#   'Humidity': 96,
#   'Clouds': 100,
#   'Wind Speed': 9.15,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Tutóia',
#   'Lat': -2.7619,
#   'Lon': -42.2744,
#   'Max_temp': 79.36,
#   'Humidity': 79,
#   'Clouds': 32,
#   'Wind Speed': 6.42,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lon': 152.4333,
#   'Max_temp': 82,
#   'Humidity': 77,
#   'Clouds': 95,
#   'Wind Speed': 2.73,
#   'Country': 'PG',
#   'Current Description': 'moderate rain'},
#  {'City': 'George Town',
#   'Lat': 5.4112,
#   'Lon': 100.3354,
#   'Max_temp': 80.53,
#   'Humidity': 92,
#   'Clouds': 20,
#   'Wind Speed': 3,
#   'Country': 'MY',
#   'Current Description': 'few clouds'},
#  {'City': 'Sinnamary',
#   'Lat': 5.3833,
#   'Lon': -52.95,
#   'Max_temp': 76.01,
#   'Humidity': 89,
#   'Clouds': 100,
#   'Wind Speed': 5.66,
#   'Country': 'GF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lon': 72.642,
#   'Max_temp': 82.08,
#   'Humidity': 78,
#   'Clouds': 100,
#   'Wind Speed': 12.5,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lon': 30.7861,
#   'Max_temp': 60.69,
#   'Humidity': 83,
#   'Clouds': 70,
#   'Wind Speed': 3.65,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lon': 45.05,
#   'Max_temp': 61.23,
#   'Humidity': 79,
#   'Clouds': 16,
#   'Wind Speed': 12.19,
#   'Country': 'MG',
#   'Current Description': 'few clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lon': 150.7967,
#   'Max_temp': 82.31,
#   'Humidity': 75,
#   'Clouds': 56,
#   'Wind Speed': 6.08,
#   'Country': 'PG',
#   'Current Description': 'light rain'},
#  {'City': 'Neyshabur',
#   'Lat': 36.2133,
#   'Lon': 58.7958,
#   'Max_temp': 79.39,
#   'Humidity': 32,
#   'Clouds': 0,
#   'Wind Speed': 2.84,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lon': -133.0374,
#   'Max_temp': 35.6,
#   'Humidity': 69,
#   'Clouds': 90,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta do Sol',
#   'Lat': 32.6667,
#   'Lon': -17.1,
# ...
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Potsdam',
#   'Lat': 52.3989,
#   'Lon': 13.0657,
#   'Max_temp': 67.01,
#   'Humidity': 73,
#   'Clouds': 54,
#   'Wind Speed': 1.99,
#   'Country': 'DE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Sudova Vyshnya',
#   'Lat': 49.7889,
#   'Lon': 23.3722,
#   'Max_temp': 56.55,
#   'Humidity': 88,
#   'Clouds': 7,
#   'Wind Speed': 4.59,
#   'Country': 'UA',
#   'Current Description': 'clear sky'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lon': -179.1667,
#   'Max_temp': 38.5,
#   'Humidity': 59,
#   'Clouds': 8,
#   'Wind Speed': 1.21,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lon': 57.7575,
#   'Max_temp': 75.45,
#   'Humidity': 78,
#   'Clouds': 40,
#   'Wind Speed': 14.43,
#   'Country': 'MU',
#   'Current Description': 'light rain'},
#  {'City': 'Waipawa',
#   'Lat': -41.4122,
#   'Lon': 175.5153,
#   'Max_temp': 53.46,
#   'Humidity': 82,
#   'Clouds': 100,
#   'Wind Speed': 6.82,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nuevo Progreso',
#   'Lat': 23.1667,
#   'Lon': -97.95,
#   'Max_temp': 97.59,
#   'Humidity': 66,
#   'Clouds': 3,
#   'Wind Speed': 7,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Witu',
#   'Lat': -2.3889,
#   'Lon': 40.4382,
#   'Max_temp': 75.47,
#   'Humidity': 87,
#   'Clouds': 15,
#   'Wind Speed': 14.63,
#   'Country': 'KE',
#   'Current Description': 'light rain'},
#  {'City': 'High Level',
#   'Lat': 58.5169,
#   'Lon': -117.136,
#   'Max_temp': 64.51,
#   'Humidity': 45,
#   'Clouds': 75,
#   'Wind Speed': 8.99,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Moyale',
#   'Lat': 3.5167,
#   'Lon': 39.0584,
#   'Max_temp': 66.78,
#   'Humidity': 70,
#   'Clouds': 53,
#   'Wind Speed': 7.9,
#   'Country': 'KE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bestöbe',
#   'Lat': 52.4994,
#   'Lon': 73.0975,
#   'Max_temp': 57.76,
#   'Humidity': 43,
#   'Clouds': 3,
#   'Wind Speed': 6.4,
#   'Country': 'KZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Manokwari',
#   'Lat': -0.8667,
#   'Lon': 134.0833,
#   'Max_temp': 79.77,
#   'Humidity': 77,
#   'Clouds': 100,
#   'Wind Speed': 1.21,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Baghmara',
#   'Lat': 23.795,
#   'Lon': 86.2085,
#   'Max_temp': 87.96,
#   'Humidity': 44,
#   'Clouds': 55,
#   'Wind Speed': 6.08,
#   'Country': 'IN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kyzyl-Suu',
#   'Lat': 42.3414,
#   'Lon': 78.0056,
#   'Max_temp': 56.79,
#   'Humidity': 62,
#   'Clouds': 100,
#   'Wind Speed': 6.82,
#   'Country': 'KG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rock Sound',
#   'Lat': 24.9,
#   'Lon': -76.2,
#   'Max_temp': 79.16,
#   'Humidity': 81,
#   'Clouds': 91,
#   'Wind Speed': 15.66,
#   'Country': 'BS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lon': 46.4667,
#   'Max_temp': 81.57,
#   'Humidity': 34,
#   'Clouds': 42,
#   'Wind Speed': 5.39,
#   'Country': 'YE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ishigaki',
#   'Lat': 24.3448,
#   'Lon': 124.1572,
#   'Max_temp': 78.93,
#   'Humidity': 100,
#   'Clouds': 75,
#   'Wind Speed': 2.3,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bugene',
#   'Lat': -1.5911,
#   'Lon': 31.1403,
#   'Max_temp': 59.36,
#   'Humidity': 79,
#   'Clouds': 63,
#   'Wind Speed': 2.66,
#   'Country': 'TZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Varhaug',
#   'Lat': 58.6147,
#   'Lon': 5.6457,
#   'Max_temp': 53.15,
#   'Humidity': 85,
#   'Clouds': 100,
#   'Wind Speed': 9.66,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Damāvand',
#   'Lat': 35.7178,
#   'Lon': 52.065,
#   'Max_temp': 75.04,
#   'Humidity': 28,
#   'Clouds': 1,
#   'Wind Speed': 2.08,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Biak',
#   'Lat': -0.9131,
#   'Lon': 122.8766,
#   'Max_temp': 77.22,
#   'Humidity': 75,
#   'Clouds': 85,
#   'Wind Speed': 4.47,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Stephenville',
#   'Lat': 32.2207,
#   'Lon': -98.2023,
#   'Max_temp': 88.14,
#   'Humidity': 63,
#   'Clouds': 40,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dudinka',
#   'Lat': 69.4058,
#   'Lon': 86.1778,
#   'Max_temp': 31.59,
#   'Humidity': 95,
#   'Clouds': 100,
#   'Wind Speed': 6.22,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lon': 129.4833,
#   'Max_temp': 74.32,
#   'Humidity': 94,
#   'Clouds': 100,
#   'Wind Speed': 3.4,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wonosobo',
#   'Lat': -7.36,
#   'Lon': 109.9025,
#   'Max_temp': 69.6,
#   'Humidity': 95,
#   'Clouds': 58,
#   'Wind Speed': 1.21,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'La Palma',
#   'Lat': 33.8464,
#   'Lon': -118.0467,
#   'Max_temp': 86.11,
#   'Humidity': 61,
#   'Clouds': 17,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': "Mil'kovo",
#   'Lat': 54.7167,
#   'Lon': 158.6167,
#   'Max_temp': 43.47,
#   'Humidity': 87,
#   'Clouds': 100,
#   'Wind Speed': 1.63,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Beyneu',
#   'Lat': 45.3167,
#   'Lon': 55.2,
#   'Max_temp': 65.53,
#   'Humidity': 50,
#   'Clouds': 1,
#   'Wind Speed': 10.47,
#   'Country': 'KZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Sobolevo',
#   'Lat': 54.4299,
#   'Lon': 31.8996,
#   'Max_temp': 54.46,
#   'Humidity': 92,
#   'Clouds': 57,
#   'Wind Speed': 6.53,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Arrondissement de Millau',
#   'Lat': 44.0833,
#   'Lon': 2.9167,
#   'Max_temp': 57.99,
#   'Humidity': 96,
#   'Clouds': 13,
#   'Wind Speed': 3.27,
#   'Country': 'FR',
#   'Current Description': 'few clouds'},
#  {'City': 'Svetlaya',
#   'Lat': 46.5389,
#   'Lon': 138.3297,
#   'Max_temp': 61.86,
#   'Humidity': 62,
#   'Clouds': 13,
#   'Wind Speed': 3.33,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Zhangaözen',
#   'Lat': 43.3,
#   'Lon': 52.8,
#   'Max_temp': 67.51,
#   'Humidity': 54,
#   'Clouds': 5,
#   'Wind Speed': 8.12,
#   'Country': 'KZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Bom Despacho',
#   'Lat': -19.7364,
#   'Lon': -45.2522,
#   'Max_temp': 67.66,
#   'Humidity': 60,
#   'Clouds': 100,
#   'Wind Speed': 4.59,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vitim',
#   'Lat': 59.4511,
#   'Lon': 112.5578,
#   'Max_temp': 48.65,
#   'Humidity': 68,
#   'Clouds': 63,
#   'Wind Speed': 7.14,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Borovskoy',
#   'Lat': 53.8,
#   'Lon': 64.15,
#   'Max_temp': 57.52,
#   'Humidity': 42,
#   'Clouds': 84,
#   'Wind Speed': 3.15,
#   'Country': 'KZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lon': 139.5,
#   'Max_temp': 60.57,
#   'Humidity': 41,
#   'Clouds': 0,
#   'Wind Speed': 3.44,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Prachatice',
#   'Lat': 49.0129,
#   'Lon': 13.9975,
#   'Max_temp': 60.55,
#   'Humidity': 97,
#   'Clouds': 63,
#   'Wind Speed': 3.09,
#   'Country': 'CZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Batagay',
#   'Lat': 67.6333,
#   'Lon': 134.6333,
#   'Max_temp': 54.03,
#   'Humidity': 39,
#   'Clouds': 85,
#   'Wind Speed': 8.55,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wundanyi',
#   'Lat': -3.4019,
#   'Lon': 38.364,
#   'Max_temp': 57.06,
#   'Humidity': 92,
#   'Clouds': 22,
#   'Wind Speed': 5.53,
#   'Country': 'KE',
#   'Current Description': 'few clouds'},
#  {'City': 'Brumado',
#   'Lat': -14.2036,
#   'Lon': -41.6653,
#   'Max_temp': 72.3,
#   'Humidity': 70,
#   'Clouds': 85,
#   'Wind Speed': 3.4,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barranca',
#   'Lat': -10.75,
#   'Lon': -77.7667,
#   'Max_temp': 64.54,
#   'Humidity': 81,
#   'Clouds': 60,
#   'Wind Speed': 10.65,
#   'Country': 'PE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Xucheng',
#   'Lat': 20.35,
#   'Lon': 110.1288,
#   'Max_temp': 77.7,
#   'Humidity': 80,
#   'Clouds': 6,
#   'Wind Speed': 6.46,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lon': 81.1185,
#   'Max_temp': 79.45,
#   'Humidity': 85,
#   'Clouds': 100,
#   'Wind Speed': 13.85,
#   'Country': 'LK',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Berkakit',
#   'Lat': 56.5807,
#   'Lon': 124.7681,
#   'Max_temp': 71.92,
#   'Humidity': 38,
#   'Clouds': 58,
#   'Wind Speed': 8.01,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Don Luan',
#   'Lat': 11.5333,
#   'Lon': 106.9167,
#   'Max_temp': 75.15,
#   'Humidity': 98,
#   'Clouds': 100,
#   'Wind Speed': 2.8,
#   'Country': 'VN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jerantut',
#   'Lat': 3.936,
#   'Lon': 102.3626,
#   'Max_temp': 72.18,
#   'Humidity': 98,
#   'Clouds': 99,
#   'Wind Speed': 0.6,
#   'Country': 'MY',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pochutla',
#   'Lat': 15.7432,
#   'Lon': -96.4661,
#   'Max_temp': 79.83,
#   'Humidity': 75,
#   'Clouds': 94,
#   'Wind Speed': 7.09,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bontang',
#   'Lat': 0.1333,
#   'Lon': 117.5,
#   'Max_temp': 77.95,
#   'Humidity': 88,
#   'Clouds': 100,
#   'Wind Speed': 6.11,
#   'Country': 'ID',
#   'Current Description': 'moderate rain'},
#  {'City': 'Moncton',
#   'Lat': 46.1159,
#   'Lon': -64.8019,
#   'Max_temp': 72.09,
#   'Humidity': 53,
#   'Clouds': 75,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nizwá',
#   'Lat': 22.9333,
#   'Lon': 57.5333,
#   'Max_temp': 84.06,
#   'Humidity': 63,
#   'Clouds': 0,
#   'Wind Speed': 3.36,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'Ellensburg',
#   'Lat': 46.9965,
#   'Lon': -120.5479,
#   'Max_temp': 62.24,
#   'Humidity': 55,
#   'Clouds': 98,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marshfield',
#   'Lat': 44.6689,
#   'Lon': -90.1718,
#   'Max_temp': 83.64,
#   'Humidity': 76,
#   'Clouds': 9,
#   'Wind Speed': 12.88,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Vidim',
#   'Lat': 56.4088,
#   'Lon': 103.1106,
#   'Max_temp': 48.04,
#   'Humidity': 70,
#   'Clouds': 7,
#   'Wind Speed': 7.63,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Villazón',
#   'Lat': -22.0866,
#   'Lon': -65.5942,
#   'Max_temp': 45.86,
#   'Humidity': 12,
#   'Clouds': 0,
#   'Wind Speed': 10.87,
#   'Country': 'BO',
#   'Current Description': 'clear sky'},
#  {'City': 'Szany',
#   'Lat': 47.4642,
#   'Lon': 17.304,
#   'Max_temp': 60.98,
#   'Humidity': 100,
#   'Clouds': 0,
#   'Wind Speed': 6.04,
#   'Country': 'HU',
#   'Current Description': 'clear sky'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8006,
#   'Lon': 130.4114,
#   'Max_temp': 49.06,
#   'Humidity': 52,
#   'Clouds': 96,
#   'Wind Speed': 8.48,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Denpasar',
#   'Lat': -8.65,
#   'Lon': 115.2167,
#   'Max_temp': 78.46,
#   'Humidity': 100,
#   'Clouds': 20,
#   'Wind Speed': 2.39,
#   'Country': 'ID',
#   'Current Description': 'few clouds'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lon': 166.4372,
#   'Max_temp': 66.9,
#   'Humidity': 39,
#   'Clouds': 6,
#   'Wind Speed': 6.58,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Bara',
#   'Lat': 10.3744,
#   'Lon': 10.7288,
#   'Max_temp': 80.22,
#   'Humidity': 63,
#   'Clouds': 100,
#   'Wind Speed': 4.52,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint Lawrence',
#   'Lat': 36.0553,
#   'Lon': 14.204,
#   'Max_temp': 69.85,
#   'Humidity': 82,
#   'Clouds': 42,
#   'Wind Speed': 2.06,
#   'Country': 'MT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kiryat Gat',
#   'Lat': 31.61,
#   'Lon': 34.7642,
#   'Max_temp': 68.68,
#   'Humidity': 74,
#   'Clouds': 0,
#   'Wind Speed': 1.36,
#   'Country': 'IL',
#   'Current Description': 'clear sky'},
#  {'City': 'Chunskiy',
#   'Lat': 56.0815,
#   'Lon': 99.6342,
#   'Max_temp': 49.77,
#   'Humidity': 71,
#   'Clouds': 72,
#   'Wind Speed': 7.14,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Adelaide',
#   'Lat': -34.9333,
#   'Lon': 138.6,
#   'Max_temp': 59.56,
#   'Humidity': 70,
#   'Clouds': 0,
#   'Wind Speed': 4,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Krasne',
#   'Lat': 49.9145,
#   'Lon': 24.6134,
#   'Max_temp': 56.55,
#   'Humidity': 92,
#   'Clouds': 29,
#   'Wind Speed': 3.91,
#   'Country': 'UA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Moose Factory',
#   'Lat': 51.2585,
#   'Lon': -80.6094,
#   'Max_temp': 73.4,
#   'Humidity': 68,
#   'Clouds': 75,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lon': 158.6483,
#   'Max_temp': 43.39,
#   'Humidity': 100,
#   'Clouds': 90,
#   'Wind Speed': 3.87,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Praia',
#   'Lat': 14.9215,
#   'Lon': -23.5087,
#   'Max_temp': 73.94,
#   'Humidity': 73,
#   'Clouds': 75,
#   'Wind Speed': 18.41,
#   'Country': 'CV',
#   'Current Description': 'broken clouds'},
#  {'City': 'Birao',
#   'Lat': 10.2849,
#   'Lon': 22.7882,
#   'Max_temp': 77.94,
#   'Humidity': 67,
#   'Clouds': 36,
#   'Wind Speed': 4,
#   'Country': 'CF',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gōtsuchō',
#   'Lat': 35,
#   'Lon': 132.2167,
#   'Max_temp': 71.71,
#   'Humidity': 68,
#   'Clouds': 77,
#   'Wind Speed': 3.47,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'Praia da Vitória',
#   'Lat': 38.7333,
#   'Lon': -27.0667,
#   'Max_temp': 66.45,
#   'Humidity': 88,
#   'Clouds': 20,
#   'Wind Speed': 4.23,
#   'Country': 'PT',
#   'Current Description': 'few clouds'},
#  {'City': 'Salé',
#   'Lat': 34.0389,
#   'Lon': -6.8166,
#   'Max_temp': 68.68,
#   'Humidity': 83,
#   'Clouds': 39,
#   'Wind Speed': 4.61,
#   'Country': 'MA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Central Point',
#   'Lat': 42.376,
#   'Lon': -122.9164,
#   'Max_temp': 74.17,
#   'Humidity': 35,
#   'Clouds': 61,
#   'Wind Speed': 8.99,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Zverinogolovskoye',
#   'Lat': 54.4586,
#   'Lon': 64.8542,
#   'Max_temp': 56.14,
#   'Humidity': 47,
#   'Clouds': 21,
#   'Wind Speed': 3.02,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Semnan',
#   'Lat': 35.5729,
#   'Lon': 53.3971,
#   'Max_temp': 80.83,
#   'Humidity': 15,
#   'Clouds': 0,
#   'Wind Speed': 3.42,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Bogandinskiy',
#   'Lat': 56.8937,
#   'Lon': 65.8938,
#   'Max_temp': 55.67,
#   'Humidity': 63,
#   'Clouds': 26,
#   'Wind Speed': 7.2,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lon': 111.5,
#   'Max_temp': 36.91,
#   'Humidity': 75,
#   'Clouds': 93,
#   'Wind Speed': 26.33,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chifeng',
#   'Lat': 42.2683,
#   'Lon': 118.9636,
#   'Max_temp': 67.62,
#   'Humidity': 44,
#   'Clouds': 95,
#   'Wind Speed': 6.13,
#   'Country': 'CN',
#   'Current Description': 'light rain'},
#  {'City': 'Ca Mau',
#   'Lat': 9.1769,
#   'Lon': 105.15,
#   'Max_temp': 79.7,
#   'Humidity': 84,
#   'Clouds': 99,
#   'Wind Speed': 6.13,
#   'Country': 'VN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chingirlau',
#   'Lat': 51.095,
#   'Lon': 54.0814,
#   'Max_temp': 63.21,
#   'Humidity': 45,
#   'Clouds': 65,
#   'Wind Speed': 6.78,
#   'Country': 'KZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nampula',
#   'Lat': -15.1165,
#   'Lon': 39.2666,
#   'Max_temp': 64.35,
#   'Humidity': 94,
#   'Clouds': 75,
#   'Wind Speed': 10.36,
#   'Country': 'MZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Gambo',
#   'Lat': 4.6482,
#   'Lon': 22.2633,
#   'Max_temp': 69.03,
#   'Humidity': 97,
#   'Clouds': 56,
#   'Wind Speed': 0.87,
#   'Country': 'CF',
#   'Current Description': 'broken clouds'},
#  {'City': 'Taunggyi',
#   'Lat': 20.7833,
#   'Lon': 97.0333,
#   'Max_temp': 63.46,
#   'Humidity': 97,
#   'Clouds': 100,
#   'Wind Speed': 3.06,
#   'Country': 'MM',
#   'Current Description': 'overcast clouds'}]

# %%
# Convert the array of dictionaries to Pandas DataFrame
#city_data_df= pd.DataFrame(city_data)
#new_column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
#city_data_df=city_data_df[new_column_order]
#city_data_df.head(10)

# %%
weather_data_df=pd.DataFrame(city_df)
weather_data_df.head()
# Out:
#                City      Lat       Lon  Max_temp  Humidity  Clouds  \
# 0  Coahuayana Viejo  18.7333 -103.6833     89.35        54      79
# 1             Bluff -46.6000  168.3333     49.80        80      61
# 2              Tual  -5.6667  132.7500     81.27        78     100
# 3            Pangai -19.8000 -174.3500     80.71        65      20
# 4             Dabat  12.9842   37.7650     62.71        33      96
#
#    Wind Speed Country Current Description
# 0        6.73      MX       broken clouds
# 1        8.32      NZ       broken clouds
# 2       14.43      ID     overcast clouds
# 3        6.91      TO          few clouds
# 4        5.26      ET     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file)
